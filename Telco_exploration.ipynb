# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

Telco = pd.read_csv (r'/Users/mindyshiben/codeup-data-science/Telco.csv')
print (Telco)
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0     0002-ORFBO  Female                  0     Yes        Yes              1
# 1     0003-MKNFE    Male                  0      No         No              2
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# ...          ...     ...                ...     ...        ...            ...
# 7044  9987-LUTYD  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
# 7046  9992-UJOEL    Male                  0      No         No              1
# 7047  9993-LHIEB    Male                  0     Yes        Yes              1
# 7048  9995-HOTOH    Male                  0     Yes        Yes              0
#
# ...

# %%
Telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7049 entries, 0 to 7048
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   customer_id             7049 non-null   object
#  1   gender                  7049 non-null   object
#  2   is_senior_citizen       7049 non-null   int64
#  3   partner                 7049 non-null   object
#  4   dependents              7049 non-null   object
#  5   phone_service           7049 non-null   int64
#  6   internet_service        7049 non-null   int64
#  7   contract_type           7049 non-null   int64
#  8   payment_type            7049 non-null   object
#  9   monthly_charges         7049 non-null   float64
#  10  total_charges           7038 non-null   float64
#  11  churn                   7049 non-null   object
#  12  tenure                  7049 non-null   float64
#  13  is_female               7049 non-null   bool
# ...

# %%
Telco.head()
# Out:
#   customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 0  0002-ORFBO  Female                  0     Yes        Yes              1
# 1  0003-MKNFE    Male                  0      No         No              2
# 2  0004-TLHLJ    Male                  0      No         No              1
# 3  0011-IGKFF    Male                  1     Yes         No              1
# 4  0013-EXCHZ  Female                  1     Yes         No              1
#
#    internet_service  contract_type      payment_type  monthly_charges  ...  \
# 0                 1              1      Mailed check             65.6  ...
# 1                 1              0      Mailed check             59.9  ...
# 2                 2              0  Electronic check             73.9  ...
# 3                 2              0  Electronic check             98.0  ...
# 4                 2              0      Mailed check             83.9  ...
#
# ...

# %%
len(Telco[Telco.has_churned == True])
# Out:
# 1870

# %%
len(Telco[Telco.has_churned == False])
# Out:
# 5179

# %%
round(len(Telco[Telco.has_churned == True])/len(Telco),2)
# Out:
# 0.27

# %%
# How many customers have churned?

# 1870, 27%

# %%
churned = Telco[Telco.has_churned == True]
churned
# Out:
#      customer_id  gender  is_senior_citizen partner dependents  phone_service  \
# 2     0004-TLHLJ    Male                  0      No         No              1
# 3     0011-IGKFF    Male                  1     Yes         No              1
# 4     0013-EXCHZ  Female                  1     Yes         No              1
# 18    0022-TCJCI    Male                  1      No         No              1
# 19    0023-HGHWL    Male                  1      No         No              0
# ...          ...     ...                ...     ...        ...            ...
# 7023  9965-YOKZB    Male                  1      No         No              2
# 7031  0032-PGELS  Female                  0     Yes        Yes              0
# 7042  9985-MWVIX  Female                  0      No         No              1
# 7043  9986-BONCE  Female                  0      No         No              1
# 7045  9992-RRAMN    Male                  0     Yes         No              2
#
# ...

# %%
stayed = Telco[Telco.has_churned == False]
len(stayed)
# Out:
# 5179

# %%
len(churned[churned.gender == 'Male'])
# Out:
# 930

# %%
len(churned[churned.gender == 'Female'])
# Out:
# 940

# %%
# gender does not seem to play a role in churn

# %%
len(churned[churned.is_senior_citizen == 1])/len(churned)
# % of churned customers that are senior
# Out:
# 0.2545454545454545

# %%
len(Telco[Telco.is_senior_citizen == 1])/len(Telco)
# % of seniors in all customers
# Out:
# 0.16200879557384026

# %%
seniors = Telco[Telco.is_senior_citizen == 1]

# %%
len(stayed[stayed.is_senior_citizen== 1])/len(stayed)
# Out:
# 0.1285962541031087

# %%
# senior citizens may be more likely to churn
# amongst customers that stayed, 13% are seniors whereas 25% of churned customers are seniors

# %%
groupby.churned.payment_type
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/s4/hmz6ljm533vgpm_bhv59yw0m0000gn/T/ipykernel_1525/4092486990.py in <module>
# ----> 1 groupby.churned.payment_type
#
# NameError: name 'groupby' is not defined
